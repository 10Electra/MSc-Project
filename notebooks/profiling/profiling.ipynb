# %%
import line_profiler as lp
import linecache                # <— grabs arbitrary source lines
from pathlib import Path

# 1. Load the .lprof file -----------------------------------------------------
stats = lp.load_stats(Path("fuse_meshes.py.lprof"))

# 2. Find the record for the function you care about -------------------------
key = ('src/superprimitive_fusion/fuse_meshes.py',   # file
       22,                                           # first-line number of the function
       'mesh_fusion')                                # function name
timings = stats.timings[key]

# 3. Convert to seconds and sort by total time -------------------------------
unit = stats.unit                     # 1e-06 by default -> micro-seconds
timings_sorted = sorted(timings, key=lambda x: x[2], reverse=True)

# 4. Pretty-print with source code -------------------------------------------
filename = key[0]
print(f"Hot lines in {filename} · function {key[2]}\n")
print(f"{'Line':>5} {'Time (ms)':>10} {'Hits':>7}  Code")
print("-" * 60)
for lineno, hits, t in timings_sorted:
    code = linecache.getline('../../'+filename, lineno).rstrip().lstrip()
    print(f"{lineno:5} {t*unit*1000:10.2f} {hits:7}  {code}")
# Out:
# Hot lines in src/superprimitive_fusion/fuse_meshes.py · function mesh_fusion
#
#  Line  Time (ms)    Hits  Code
# ------------------------------------------------------------
#    77    1052.19       5  trilat_shifted_pts = trilateral_shift(trilat_shifted_pts, normals, local_spacing, local_density, overlap_idx, tree, r_alpha, h_alpha)
#    52     445.19       1  normals = smooth_normals(points, normals, k=8, T=0.7, n_iters=5)
#    80     175.09       2  cluster_mapping, clustered_overlap_pnts, clustered_overlap_cols, clustered_overlap_nrms = merge_nearby_clusters(
#   144      22.24       2  overlap_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
#    64      20.29       1  overlap_idx, overlap_mask = compute_overlap_set(points, normals, local_spacing, scan_ids, h_alpha, r_alpha, tree)
#   163      19.70       1  trimmed_overlap_mesh = topological_trim(overlap_mesh, relevant_boundary_edges)
#    53      18.68       1  local_spacing_1, local_density_1 = calc_local_spacing(mesh1.vertices, np.asarray(mesh1_o3d.vertices))
#    54      17.48       1  local_spacing_2, local_density_2 = calc_local_spacing(mesh2.vertices, np.asarray(mesh2_o3d.vertices))
#    29       8.05       1  mesh1_o3d = trimesh_to_o3d(mesh1)
#    30       7.55       1  mesh2_o3d = trimesh_to_o3d(mesh2)
#   170       2.70       1  triangles=o3d.utility.Vector3iVector(fused_mesh_triangles)
#   180       1.97       1  fused_mesh.remove_non_manifold_edges()
#   150       1.72       1  overlap_mesh.remove_non_manifold_edges()
#    40       1.42       1  tree = o3d.geometry.KDTreeFlann(points.T)
#    72       1.31       1  boundary_edges = find_boundary_edges(nonoverlap_tris)
#   177       0.70       1  fused_mesh.remove_duplicated_triangles()
#   148       0.58       1  overlap_mesh.remove_duplicated_triangles()
#    99       0.49       2  overlap_any_idx = np.unique(
#   178       0.35       1  fused_mesh.remove_duplicated_vertices()
#   147       0.31       1  overlap_mesh.remove_duplicated_vertices()
#   118       0.24       1  border_idx_from  = np.array(range(len(points)))[border_mask]
#   121       0.23       1  free_idx_from    = np.array(range(len(points)))[nonoverlap_nonborder_mask]
#    71       0.18       1  nonoverlap_tris = all_tris[~np.all(overlap_mask[all_tris], axis=1)]
#   100       0.12       1  all_tris[tri_has_overlap_any]
#    97       0.12       1  tri_has_overlap_any = overlap_mask[all_tris].any(axis=1)
#   174       0.08       1  fused_mesh.vertex_colors = get_o3d_colours_from_trimesh(new_colours)
#   182       0.08       1  fused_mesh.compute_vertex_normals()
#    42       0.06       1  mesh1_o3d.compute_vertex_normals()
#    60       0.06       3  global_avg_spacing = (1/len(local_spacings)) * np.sum([(1/len(localspacing)) * np.sum(localspacing) for localspacing in local_spacings])
#   131       0.06       1  pcd.colors = get_o3d_colours_from_trimesh(new_colours[:n_overlap])
#   151       0.06       1  overlap_mesh.compute_vertex_normals()
#   156       0.06       1  vidx = np.unique(mapping[boundary_edges])
#   173       0.05       1  new_colours = np.clip(new_colours, 0, 255)
#    43       0.05       1  mesh2_o3d.compute_vertex_normals()
#   113       0.04       1  new_points  = np.concat([clustered_overlap_pnts, trilat_shifted_pts[border_mask], trilat_shifted_pts[nonoverlap_nonborder_mask]])
#   114       0.04       1  new_colours = np.concat([clustered_overlap_cols, colours[border_mask],            colours[nonoverlap_nonborder_mask]])
#   115       0.04       1  new_normals = np.concat([clustered_overlap_nrms, normals[border_mask],            normals[nonoverlap_nonborder_mask]])
#    49       0.04       3  scan_ids = np.concat([np.ones(len(these_points)) * i for (i, these_points) in enumerate(pointclouds)])
#    34       0.03       1  points = np.vstack(pointclouds)
#   176       0.03       1  fused_mesh.remove_unreferenced_vertices()
#    95       0.02       1  all_tris = np.vstack([tris1, tris2_shifted])
#   161       0.02       1  relevant_boundary_edges = mapped_boundary_edges[np.all(mapped_boundary_edges<len(v), axis=1)]
#    69       0.02       1  all_tris = np.concat([tris1, tris2+len(points1)])
#   130       0.02       1  pcd.points  = o3d.utility.Vector3dVector(new_points[:n_overlap])
#   166       0.02       1  fused_mesh_triangles = np.concatenate([trimmed_overlap_tris, mapping[nonoverlap_tris]], axis=0)
#   168       0.01       2  fused_mesh = o3d.geometry.TriangleMesh(
#    47       0.01       1  normals = np.concat([normals1, normals2], axis=0)
#    94       0.01       1  tris2_shifted = tris2 + len(points1)
#   105       0.01       1  border_mask[cluster_mapping!=-1] = False # Remove overlap verts
#   122       0.01       1  free_idx_to      = np.array(range(n_free)) + n_overlap + n_border
#    56       0.01       1  local_spacing = np.concat(local_spacings)
#   104       0.01       1  border_mask[overlap_any_idx] = True # Add both border verts and overlap verts
#   149       0.01       1  overlap_mesh.remove_degenerate_triangles()
#   134       0.01       1  pcd.normals = o3d.utility.Vector3dVector(new_normals[:n_overlap])
#    91       0.01       1  tris1 = np.asarray(mesh1_o3d.triangles)
#   108       0.01       1  nonoverlap_nonborder_mask[cluster_mapping==-1] = True
#   111       0.01       1  n_overlap, n_border, n_free = len(clustered_overlap_pnts), border_mask.sum(), nonoverlap_nonborder_mask.sum()
#   119       0.01       1  border_idx_to    = np.array(range(n_border)) + n_overlap
#   142       0.01       1  radii    = o3d.utility.DoubleVector([ball_r, ball_r * 1.5])
#   153       0.01       1  overlap_mesh.vertex_colors = pcd.colors
#   155       0.01       1  v = np.asarray(overlap_mesh.vertices)
#   169       0.01       1  vertices=o3d.utility.Vector3dVector(new_points),
#   179       0.01       1  fused_mesh.remove_degenerate_triangles()
#    45       0.01       1  normals1 = np.asarray(mesh1_o3d.vertex_normals)
#    67       0.00       1  tris1 = np.asarray(mesh1_o3d.triangles)
#   109       0.00       1  nonoverlap_nonborder_mask[border_mask] = False
#   129       0.00       1  pcd = o3d.geometry.PointCloud()
#   184       0.00       1  return fused_mesh
#    38       0.00       1  colours = np.concat([colours1, colours2])
#    58       0.00       1  local_density = np.concat((local_density_1, local_density_2))
#   157       0.00       1  vidx = vidx[vidx < len(v)]
#   165       0.00       1  trimmed_overlap_tris = np.asarray(trimmed_overlap_mesh.triangles)
#    36       0.00       1  colours1 = mesh1.visual.vertex_colors
#    37       0.00       1  colours2 = mesh2.visual.vertex_colors
#    92       0.00       1  tris2 = np.asarray(mesh2_o3d.triangles)
#   103       0.00       1  border_mask = np.zeros(len(points), dtype=bool)
#   125       0.00       1  mapping[border_idx_from] = border_idx_to
#   160       0.00       1  mapped_boundary_edges = mapping[boundary_edges]
#    31       0.00       1  points1 = np.asarray(mesh1.vertices)
#    46       0.00       1  normals2 = np.asarray(mesh2_o3d.vertex_normals)
#    55       0.00       1  local_spacings = (local_spacing_1, local_spacing_2)
#    68       0.00       1  tris2 = np.asarray(mesh2_o3d.triangles)
#    76       0.00       6  for i in range(5):
#    86       0.00       1  h_alpha=h_alpha,
#   107       0.00       1  nonoverlap_nonborder_mask = np.zeros(len(points), dtype=bool)
#   133       0.00       1  if new_normals[:n_overlap] is not None:
#   141       0.00       1  ball_r   = 1.1 * global_avg_spacing
#    32       0.00       1  points2 = np.asarray(mesh2.vertices)
#    33       0.00       1  pointclouds = (points1, points2)
#    63       0.00       1  r_alpha = 2
#    75       0.00       1  trilat_shifted_pts = points
#    81       0.00       1  trilat_shifted_pts=trilat_shifted_pts,
#    82       0.00       1  normals=normals,
#    83       0.00       1  colours=colours,
#    84       0.00       1  overlap_mask=overlap_mask,
#    85       0.00       1  global_avg_spacing=global_avg_spacing,
#    87       0.00       1  find_cyl_neighbours=find_cyl_neighbours,
#   124       0.00       1  mapping = cluster_mapping # contains mappings for overlap area already
#   126       0.00       1  mapping[free_idx_from]   = free_idx_to
#   145       0.00       1  pcd, radii)
